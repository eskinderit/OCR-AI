# %% [markdown]
# # Llava - Digitalize Vespa VL3T "Struzzo" (1956) Instruction Manual

# %% [markdown]
# The original instruction manual, published in 1956, has no digital version that is available online, however, a scan of the instruction manual (in italian) was found for it.
# In the following section the original manual will be converted to a digital version using Llava 7B (through Ollama).
# Later, the document will be split into chunks, to perform RAG.

# %%
! systemctl start ollama
! ollama pull llava:7b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling 170370233dd5...   0% ▕                ▏    0 B/4.1 GB                  pulling manifest
# pulling 170370233dd5...   0% ▕                ▏    0 B/4.1 GB                  pulling manifest
# pulling 170370233dd5...   0% ▕                ▏    0 B/4.1 GB                  pulling manifest
# pulling 170370233dd5...   0% ▕                ▏    0 B/4.1 GB                  pulling manifest
# ...

# %%
import ollama
res = ollama.chat(
	model="llava:7b",
	messages=[
		{
			'role': 'user',
			'content': 'Transcribe the content of the image',
			'images': ['../imgs/vespa_manual_1.png']
		}
	]
)

print(res['message']['content'])
# Out:
#  The text in the image is written in Italian, and it appears to be an old document or notice. Here's a transcription of the visible content:
#
# ```
# AVVERTEZZE E REGI UTENTI
#
# La presente è una nota per i lavoratori della Società Italiana per le Vie Ferrate, S.p.A.
#
# Soprintende: il lavoratore che non ossera il presente, si rendere colpe di legge attualmente vigenti.
#
# Ripetizione del presente per il lavoratore che vi sia: si pregiude di recitarlo alla propria vista e ai suoi co-lavoratori in modo che questi possano essere informati e conoscenza delle regole che debbono seguire. In caso di non osservanza, i lavoratori verranno convocati al Tribunale del Lavoro per accertarsi che siano consapevoli della normativa e dei compiti da eseguire.
# ```
#
# Please note that the image is slightly rotated and may contain errors due to the angle of the text.

# %% [markdown]
# This result is deeply hallucinated
